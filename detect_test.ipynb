# %%
from ultralytics import YOLO
from PIL import Image

# %%
im = Image.open("./sources/Ann_Fulton_Club.jpg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=512x346>

# %%
model = YOLO("./yolov8x.pt")

# %%
results = model.predict(source="./sources/Ann_Fulton_Club.jpg", save=True, device="mps")
# Out:
# image 1/1 /Users/nobu/yolo_project/sources/Ann_Fulton_Club.jpg: 448x640 7 persons, 5 chairs, 131.6ms
# Speed: 6.3ms preprocess, 131.6ms inference, 714.8ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict3

# %%
detect_im = Image.open("./runs/detect/predict3/Ann_Fulton_Club.jpg")
detect_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x346>
